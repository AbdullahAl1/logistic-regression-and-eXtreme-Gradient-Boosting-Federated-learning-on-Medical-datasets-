# %%
import flwr as fl
import utils
from sklearn.linear_model import LogisticRegression


# Start Flower server for five rounds of federated learning
if __name__ == "__main__":
    model = LogisticRegression()
    utils.set_initial_params(model, n_classes=2, n_features=30)
    strategy = fl.server.strategy.FedAvg(
        min_available_clients=2,
        fit_metrics_aggregation_fn=utils.weighted_average,
        evaluate_metrics_aggregation_fn=utils.weighted_average,
    )
    fl.server.start_server(
        server_address="127.0.0.1:8080",
        strategy=strategy,
        config=fl.server.ServerConfig(num_rounds=25),
    )
# Out:
# INFO flwr 2024-05-02 16:19:18,094 | app.py:163 | Starting Flower server, config: ServerConfig(num_rounds=25, round_timeout=None)
# INFO flwr 2024-05-02 16:19:18,112 | app.py:176 | Flower ECE: gRPC server running (25 rounds), SSL is disabled
# INFO flwr 2024-05-02 16:19:18,113 | server.py:89 | Initializing global parameters
# INFO flwr 2024-05-02 16:19:18,113 | server.py:276 | Requesting initial parameters from one random client
# INFO flwr 2024-05-02 16:19:20,008 | server.py:280 | Received initial parameters from one random client
# INFO flwr 2024-05-02 16:19:20,008 | server.py:91 | Evaluating initial parameters
# INFO flwr 2024-05-02 16:19:20,009 | server.py:104 | FL starting
# DEBUG flwr 2024-05-02 16:19:22,214 | server.py:222 | fit_round 1: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,228 | server.py:236 | fit_round 1 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,230 | server.py:173 | evaluate_round 1: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,235 | server.py:187 | evaluate_round 1 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,236 | server.py:222 | fit_round 2: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,250 | server.py:236 | fit_round 2 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,252 | server.py:173 | evaluate_round 2: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,258 | server.py:187 | evaluate_round 2 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,259 | server.py:222 | fit_round 3: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,273 | server.py:236 | fit_round 3 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,275 | server.py:173 | evaluate_round 3: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,280 | server.py:187 | evaluate_round 3 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,281 | server.py:222 | fit_round 4: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,294 | server.py:236 | fit_round 4 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,296 | server.py:173 | evaluate_round 4: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,301 | server.py:187 | evaluate_round 4 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,301 | server.py:222 | fit_round 5: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,315 | server.py:236 | fit_round 5 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,316 | server.py:173 | evaluate_round 5: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,322 | server.py:187 | evaluate_round 5 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,322 | server.py:222 | fit_round 6: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,336 | server.py:236 | fit_round 6 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,338 | server.py:173 | evaluate_round 6: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,343 | server.py:187 | evaluate_round 6 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,344 | server.py:222 | fit_round 7: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,358 | server.py:236 | fit_round 7 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,359 | server.py:173 | evaluate_round 7: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,365 | server.py:187 | evaluate_round 7 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,365 | server.py:222 | fit_round 8: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,380 | server.py:236 | fit_round 8 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,381 | server.py:173 | evaluate_round 8: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,387 | server.py:187 | evaluate_round 8 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,387 | server.py:222 | fit_round 9: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,401 | server.py:236 | fit_round 9 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,403 | server.py:173 | evaluate_round 9: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,408 | server.py:187 | evaluate_round 9 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,409 | server.py:222 | fit_round 10: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,423 | server.py:236 | fit_round 10 received 2 results and 0 failures
# [(307, {'train_accuracy': 0.7915309446254072}), (307, {'train_accuracy': 0.7198697068403909})]
# [(77, {'test_accuracy': 0.7272727272727273}), (77, {'test_accuracy': 0.7662337662337663})]
# [(307, {'train_accuracy': 0.7915309446254072}), (307, {'train_accuracy': 0.7719869706840391})]
# [(77, {'test_accuracy': 0.7662337662337663}), (77, {'test_accuracy': 0.7272727272727273})]
# [(307, {'train_accuracy': 0.7980456026058632}), (307, {'train_accuracy': 0.7785016286644951})]
# [(77, {'test_accuracy': 0.6883116883116883}), (77, {'test_accuracy': 0.7792207792207793})]
# [(307, {'train_accuracy': 0.7785016286644951}), (307, {'train_accuracy': 0.7882736156351792})]
# [(77, {'test_accuracy': 0.7792207792207793}), (77, {'test_accuracy': 0.6753246753246753})]
# [(307, {'train_accuracy': 0.7882736156351792}), (307, {'train_accuracy': 0.7882736156351792})]
# [(77, {'test_accuracy': 0.7012987012987013}), (77, {'test_accuracy': 0.7792207792207793})]
# [(307, {'train_accuracy': 0.7980456026058632}), (307, {'train_accuracy': 0.7817589576547231})]
# [(77, {'test_accuracy': 0.7792207792207793}), (77, {'test_accuracy': 0.7142857142857143})]
# [(307, {'train_accuracy': 0.7817589576547231}), (307, {'train_accuracy': 0.7850162866449512})]
# [(77, {'test_accuracy': 0.7922077922077922}), (77, {'test_accuracy': 0.6883116883116883})]
# [(307, {'train_accuracy': 0.7850162866449512}), (307, {'train_accuracy': 0.7785016286644951})]
# [(77, {'test_accuracy': 0.7012987012987013}), (77, {'test_accuracy': 0.7922077922077922})]
# [(307, {'train_accuracy': 0.7882736156351792}), (307, {'train_accuracy': 0.7785016286644951})]
# [(77, {'test_accuracy': 0.6883116883116883}), (77, {'test_accuracy': 0.7922077922077922})]
# DEBUG flwr 2024-05-02 16:19:22,425 | server.py:173 | evaluate_round 10: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,430 | server.py:187 | evaluate_round 10 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,431 | server.py:222 | fit_round 11: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,445 | server.py:236 | fit_round 11 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,446 | server.py:173 | evaluate_round 11: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,451 | server.py:187 | evaluate_round 11 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,452 | server.py:222 | fit_round 12: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,466 | server.py:236 | fit_round 12 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,467 | server.py:173 | evaluate_round 12: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,473 | server.py:187 | evaluate_round 12 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,474 | server.py:222 | fit_round 13: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,487 | server.py:236 | fit_round 13 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,488 | server.py:173 | evaluate_round 13: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,494 | server.py:187 | evaluate_round 13 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,494 | server.py:222 | fit_round 14: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,508 | server.py:236 | fit_round 14 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,510 | server.py:173 | evaluate_round 14: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,515 | server.py:187 | evaluate_round 14 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,515 | server.py:222 | fit_round 15: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,529 | server.py:236 | fit_round 15 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,530 | server.py:173 | evaluate_round 15: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,535 | server.py:187 | evaluate_round 15 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,536 | server.py:222 | fit_round 16: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,549 | server.py:236 | fit_round 16 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,551 | server.py:173 | evaluate_round 16: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,556 | server.py:187 | evaluate_round 16 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,557 | server.py:222 | fit_round 17: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,570 | server.py:236 | fit_round 17 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,572 | server.py:173 | evaluate_round 17: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,577 | server.py:187 | evaluate_round 17 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,577 | server.py:222 | fit_round 18: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,590 | server.py:236 | fit_round 18 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,592 | server.py:173 | evaluate_round 18: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,597 | server.py:187 | evaluate_round 18 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,598 | server.py:222 | fit_round 19: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,611 | server.py:236 | fit_round 19 received 2 results and 0 failures
# [(307, {'train_accuracy': 0.7785016286644951}), (307, {'train_accuracy': 0.7850162866449512})]
# [(77, {'test_accuracy': 0.6883116883116883}), (77, {'test_accuracy': 0.7922077922077922})]
# [(307, {'train_accuracy': 0.7785016286644951}), (307, {'train_accuracy': 0.7850162866449512})]
# [(77, {'test_accuracy': 0.7922077922077922}), (77, {'test_accuracy': 0.6883116883116883})]
# [(307, {'train_accuracy': 0.7785016286644951}), (307, {'train_accuracy': 0.7817589576547231})]
# [(77, {'test_accuracy': 0.6753246753246753}), (77, {'test_accuracy': 0.7922077922077922})]
# [(307, {'train_accuracy': 0.7785016286644951}), (307, {'train_accuracy': 0.7882736156351792})]
# [(77, {'test_accuracy': 0.7922077922077922}), (77, {'test_accuracy': 0.6883116883116883})]
# [(307, {'train_accuracy': 0.7817589576547231}), (307, {'train_accuracy': 0.7850162866449512})]
# [(77, {'test_accuracy': 0.7922077922077922}), (77, {'test_accuracy': 0.6883116883116883})]
# [(307, {'train_accuracy': 0.7850162866449512}), (307, {'train_accuracy': 0.7752442996742671})]
# [(77, {'test_accuracy': 0.7922077922077922}), (77, {'test_accuracy': 0.6753246753246753})]
# [(307, {'train_accuracy': 0.7882736156351792}), (307, {'train_accuracy': 0.7785016286644951})]
# [(77, {'test_accuracy': 0.7922077922077922}), (77, {'test_accuracy': 0.6753246753246753})]
# [(307, {'train_accuracy': 0.7817589576547231}), (307, {'train_accuracy': 0.7817589576547231})]
# [(77, {'test_accuracy': 0.6753246753246753}), (77, {'test_accuracy': 0.7922077922077922})]
# [(307, {'train_accuracy': 0.7817589576547231}), (307, {'train_accuracy': 0.7817589576547231})]
# [(77, {'test_accuracy': 0.6753246753246753}), (77, {'test_accuracy': 0.7922077922077922})]
# DEBUG flwr 2024-05-02 16:19:22,613 | server.py:173 | evaluate_round 19: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,618 | server.py:187 | evaluate_round 19 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,618 | server.py:222 | fit_round 20: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,632 | server.py:236 | fit_round 20 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,634 | server.py:173 | evaluate_round 20: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,639 | server.py:187 | evaluate_round 20 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,640 | server.py:222 | fit_round 21: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,654 | server.py:236 | fit_round 21 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,655 | server.py:173 | evaluate_round 21: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,661 | server.py:187 | evaluate_round 21 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,662 | server.py:222 | fit_round 22: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,676 | server.py:236 | fit_round 22 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,677 | server.py:173 | evaluate_round 22: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,683 | server.py:187 | evaluate_round 22 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,684 | server.py:222 | fit_round 23: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,697 | server.py:236 | fit_round 23 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,699 | server.py:173 | evaluate_round 23: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,704 | server.py:187 | evaluate_round 23 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,705 | server.py:222 | fit_round 24: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,720 | server.py:236 | fit_round 24 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,722 | server.py:173 | evaluate_round 24: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,727 | server.py:187 | evaluate_round 24 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,728 | server.py:222 | fit_round 25: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,742 | server.py:236 | fit_round 25 received 2 results and 0 failures
# DEBUG flwr 2024-05-02 16:19:22,743 | server.py:173 | evaluate_round 25: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-05-02 16:19:22,749 | server.py:187 | evaluate_round 25 received 2 results and 0 failures
# INFO flwr 2024-05-02 16:19:22,749 | server.py:153 | FL finished in 2.740657199999987
# INFO flwr 2024-05-02 16:19:22,749 | app.py:226 | app_fit: losses_distributed [(1, 0.5348204076290131), (2, 0.49948135018348694), (3, 0.5112961530685425), (4, 0.5107155293226242), (5, 0.5100175887346268), (6, 0.5177914500236511), (7, 0.5159332007169724), (8, 0.5217715203762054), (9, 0.5233338624238968), (10, 0.5231650322675705), (11, 0.5217432826757431), (12, 0.5207232683897018), (13, 0.5224278420209885), (14, 0.5223898887634277), (15, 0.520775705575943), (16, 0.5224471241235733), (17, 0.5195856094360352), (18, 0.5204403400421143), (19, 0.5240012258291245), (20, 0.5234610885381699), (21, 0.5246803760528564), (22, 0.5225699692964554), (23, 0.5226347595453262), (24, 0.5239129960536957), (25, 0.5241025239229202)]
# INFO flwr 2024-05-02 16:19:22,750 | app.py:227 | app_fit: metrics_distributed_fit {'train_accuracy': [(1, 0.755700325732899), (2, 0.7817589576547231), (3, 0.7882736156351792), (4, 0.7833876221498371), (5, 0.7882736156351792), (6, 0.7899022801302932), (7, 0.7833876221498371), (8, 0.7817589576547231), (9, 0.7833876221498371), (10, 0.7817589576547231), (11, 0.7817589576547231), (12, 0.7801302931596091), (13, 0.7833876221498371), (14, 0.7833876221498371), (15, 0.7801302931596091), (16, 0.7833876221498371), (17, 0.7817589576547231), (18, 0.7817589576547231), (19, 0.7833876221498371), (20, 0.7817589576547231), (21, 0.7817589576547231), (22, 0.7801302931596091), (23, 0.7817589576547231), (24, 0.7833876221498371), (25, 0.7817589576547231)]}
# INFO flwr 2024-05-02 16:19:22,750 | app.py:228 | app_fit: metrics_distributed {'test_accuracy': [(1, 0.7467532467532467), (2, 0.7467532467532467), (3, 0.7337662337662337), (4, 0.7272727272727273), (5, 0.7402597402597403), (6, 0.7467532467532467), (7, 0.7402597402597403), (8, 0.7467532467532467), (9, 0.7402597402597403), (10, 0.7402597402597403), (11, 0.7402597402597403), (12, 0.7337662337662337), (13, 0.7402597402597403), (14, 0.7402597402597403), (15, 0.7337662337662337), (16, 0.7337662337662337), (17, 0.7337662337662337), (18, 0.7337662337662337), (19, 0.7337662337662337), (20, 0.7337662337662337), (21, 0.7337662337662337), (22, 0.7337662337662337), (23, 0.7337662337662337), (24, 0.7337662337662337), (25, 0.7402597402597403)]}
# INFO flwr 2024-05-02 16:19:22,751 | app.py:229 | app_fit: losses_centralized []
# INFO flwr 2024-05-02 16:19:22,751 | app.py:230 | app_fit: metrics_centralized {}
# [(307, {'train_accuracy': 0.7817589576547231}), (307, {'train_accuracy': 0.7850162866449512})]
# [(77, {'test_accuracy': 0.6753246753246753}), (77, {'test_accuracy': 0.7922077922077922})]
# [(307, {'train_accuracy': 0.7817589576547231}), (307, {'train_accuracy': 0.7817589576547231})]
# [(77, {'test_accuracy': 0.6753246753246753}), (77, {'test_accuracy': 0.7922077922077922})]
# [(307, {'train_accuracy': 0.7850162866449512}), (307, {'train_accuracy': 0.7785016286644951})]
# [(77, {'test_accuracy': 0.7922077922077922}), (77, {'test_accuracy': 0.6753246753246753})]
# [(307, {'train_accuracy': 0.7785016286644951}), (307, {'train_accuracy': 0.7817589576547231})]
# [(77, {'test_accuracy': 0.7922077922077922}), (77, {'test_accuracy': 0.6753246753246753})]
# [(307, {'train_accuracy': 0.7817589576547231}), (307, {'train_accuracy': 0.7817589576547231})]
# [(77, {'test_accuracy': 0.7922077922077922}), (77, {'test_accuracy': 0.6753246753246753})]
# [(307, {'train_accuracy': 0.7850162866449512}), (307, {'train_accuracy': 0.7817589576547231})]
# [(77, {'test_accuracy': 0.6753246753246753}), (77, {'test_accuracy': 0.7922077922077922})]
# [(307, {'train_accuracy': 0.7817589576547231}), (307, {'train_accuracy': 0.7817589576547231})]
# [(77, {'test_accuracy': 0.7922077922077922}), (77, {'test_accuracy': 0.6883116883116883})]
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# ...
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\fafaf\anaconda3\envs\tf\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
